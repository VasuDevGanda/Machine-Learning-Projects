# %% [markdown]
# ## Assignment: Statistics Advance-3

# %% [markdown]
# ### Q1: What is Estimation Statistics? Explain point estimate and interval estimate.

# %% [markdown]
# **Ans:** It is a specified observed numerical value used to estimate an unknown population parameter.
#
# Point estimate is a single numerical value used to estimate an unknown populartion parameter.
#
# Interval estimate ia a range of values used to estimate the unknown population parameter.

# %% [markdown]
# ### Q2. Write a Python function to estimate the population mean using a sample mean and standard deviation.

# %%
import math

def estimate_population_mean(sample_mean, sample_std, sample_size):
    standard_error = sample_std / math.sqrt(sample_size)
    margin_of_error = 1.96* standard_error #Assuming a 95% CI
    
    lower_bound = sample_mean - margin_of_error
    upper_bound = sample_mean + margin_of_error
    
    return lower_bound, upper_bound

sample_mean = 50
sample_std = 10.0
sample_size = 100

lower_bound, upper_bound = estimate_population_mean(sample_mean,sample_std, sample_size)
print(f"Estimated population mean: {sample_mean} (95% confidence interval: {lower_bound} - {upper_bound})")
# Out:
# Estimated population mean: 50 (95% confidence interval: 48.04 - 51.96)

# %% [markdown]
# ### Q3: What is Hypothesis testing? Why is it used? State the importance of Hypothesis testing.

# %% [markdown]
# **Ans:** Hypothesis testing is a statistical method used to make inferences or draw conclusions about a population based on a sample of data. It involves formulating two competing hypotheses, the null hypothesis (H0) and the alternative hypothesis (H1 or HA), and using statistical evidence to determine which hypothesis is more plausible.
#
# Hypothesis testing is used for several reasons:
# - To test research hypothesis
# - To make decisions based on data
# - To assess the significance of findings
# - To generalize findings to a larger population
#
# It is important because it is a powerful statistical tool that helps researchers test hypotheses, make decisions, assess significance, and draw valid inferences about populations. It plays a crucial role in scientific research and data analysis.

# %% [markdown]
# ### Q4. Create a hypothesis that states whether the average weight of male college students is greater than the average weight of female college students.

# %% [markdown]
# **Ans:**The hypothesis can be stated as follows:
#
# Null Hypothesis (H0): The average weight of male college students is equal to or less than the average weight of female college students.
#
# Alternative Hypothesis (H1 or HA): The average weight of male college students is greater than the average weight of female college students.

# %% [markdown]
# ### Q5. Write a Python script to conduct a hypothesis test on the difference between two population means, given a sample from each population.

# %%
import scipy.stats as stats

def conduct_t_test(sample1, sample2, alpha):
    # Perform independent t-test
    t_stat, p_value = stats.ttest_ind(sample1, sample2, equal_var=False)

    # Determine whether to reject or fail to reject the null hypothesis
    if p_value < alpha:
        result = "Reject null hypothesis"
    else:
        result = "Fail to reject null hypothesis"

    return t_stat, p_value, result

# Example usage
sample1 = [15, 18, 20, 22, 24]
sample2 = [12, 14, 16, 18, 20]
alpha = 0.05

t_stat, p_value, result = conduct_t_test(sample1, sample2, alpha)

print(f"T-statistic: {t_stat}")
print(f"P-value: {p_value}")
print(f"Result: {result}")
# Out:
# T-statistic: 1.8034001919297484
# P-value: 0.10935215773256456
# Result: Fail to reject null hypothesis

# %% [markdown]
# ### Q6: What is a null and alternative hypothesis? Give some examples.

# %% [markdown]
# **Ans:** Null Hypothesis is a assumption by which you are beginning your hypothesis testing mechanism whereas alternate hypothesis is opposite to the null hypothesis.
#
# Eg.
# Null Hypothesis (Ho) : The average of height of students in a class is 160cm.
# Alternate Hypothesis (H1) : The average of height of students in a class isnot equal to 160cm.

# %% [markdown]
# ### Q7: Write down the steps involved in hypothesis testing.

# %% [markdown]
# **Ans:**
# Step 1: State the Null Hypothesis Ho and Alternate Hypothesis H1.
#
# Step 2: Collect data in a way designed to test the hypothesis and set decision boundary.
#
# Step 3: Perfrom an appropriate test or experiment.
#
# Step 4: Decide whether to reject or fail to reject the null hypothesis.
#
# Step 5: Write conclusion.

# %% [markdown]
# ### Q8. Define p-value and explain its significance in hypothesis testing.

# %% [markdown]
# **Ans:** It is a no. calculated from statistical test that describe how likely you are to have found a particular set of observations if the null hypothesis were true.
#
# P-Value is used in hypothesis testing to help decide whether to reject the null hypothesis.
#
# if p_Value < Significance_value:
#
#       Reject the null hypothesis
#
# else:
#
#     fail to reject the null hypotheis

# %% [markdown]
# ### Q9. Generate a Student's t-distribution plot using Python's matplotlib library, with the degrees of freedom parameter set to 10.

# %%
import matplotlib.pyplot as plt
from scipy.stats import t
import numpy as np 

degree_of_freedom = 10

x = np.linspace(-5,5,100)
y = t.pdf(x,degree_of_freedom)

plt.plot(x,y, color= 'r')
plt.title("T-Distribution for Degree of Freedom 10")
plt.xlabel('x')
plt.ylabel('Probability Density Function (PDF)')
plt.show()

# %% [markdown]
# ### Q10. Write a Python program to calculate the two-sample t-test for independent samples, given two random samples of equal size and a null hypothesis that the population means are equal.

# %%
import numpy as np
import scipy.stats as stats

# assuming alpha 0.05
data_group1 = np.array([14, 15, 15, 16, 13, 8, 14,
                        17, 16, 14, 19, 20, 21, 15,
                        15, 16, 16, 13, 14, 12])
data_group2 = np.array([15, 17, 14, 17, 14, 8, 12,
                        19, 19, 14, 17, 22, 24, 16,
                        13, 16, 13, 18, 15, 13])

stats.ttest_ind(a=data_group1, b=data_group2)
# Out:
# Ttest_indResult(statistic=-0.6337397070250238, pvalue=0.5300471010405257)

# %% [markdown]
# Since the P_value is greater than alpha, so we fail to reject the null hypothesis.

# %% [markdown]
# ### Q11: What is Student’s t distribution? When to use the t-Distribution.

# %% [markdown]
# **Ans:** The t-distribution, also known as the Student’s t-distribution, is a probability distribution that is used in inferential statistics when the sample size is small and the population standard deviation is unknown. It is a variation of the normal distribution with heavier tails, which makes it more appropriate for estimating the mean of a population when the sample size is small or when there is uncertainty about the population standard deviation.
#
# We use t distribution When population standard deviation is not given or population size is too small to go for z test.

# %% [markdown]
# ### Q12: What is t-statistic? State the formula for t-statistic.

# %% [markdown]
# **Ans:** The t-statistic is the ratio of the departure of the estimated value of a parameter from its hypothesized value to its standard error. It is used in hypothesis testing via Student's t-test.
#
# The formula:
#
# t = (sample mean - population mean) / (sample standard deviation / sqrt(sample size)
#
# or
#
# t = (X‾ - μ0) / (s / √n)

# %% [markdown]
# ### Q13. A coffee shop owner wants to estimate the average daily revenue for their shop. They take a random sample of 50 days and find the sample mean revenue to be $$500 With a standard deviation of $50. Estimate the population mean revenue with a 95% confidence interval.

# %% [markdown]
# ![WhatsApp%20Image%202023-07-14%20at%2010.56.25.jpg](attachment:WhatsApp%20Image%202023-07-14%20at%2010.56.25.jpg)

# %% [markdown]
# ### Q14. A researcher hypothesizes that a new drug will decrease blood pressure by 10 mmHg. They conduct a clinical trial with 100 patients and find that the sample mean decrease in blood pressure is 8 mmHg with a standard deviation of 3 mmHg. Test the hypothesis with a significance level of 0.05.

# %% [markdown]
# ![WhatsApp%20Image%202023-07-14%20at%2010.56.25.jpg](attachment:WhatsApp%20Image%202023-07-14%20at%2010.56.25.jpg)
# ![WhatsApp%20Image%202023-07-14%20at%2010.56.25-2.jpg](attachment:WhatsApp%20Image%202023-07-14%20at%2010.56.25-2.jpg)

# %% [markdown]
# ### Q15. An electronics company produces a certain type of product with a mean weight of 5 pounds and a standard deviation of 0.5 pounds. A random sample of 25 products is taken, and the sample mean weight is found to be 4.8 pounds. Test the hypothesis that the true mean weight of the products is less than 5 pounds with a significance level of 0.01.

# %% [markdown]
# ![WhatsApp%20Image%202023-07-14%20at%2010.56.26.jpg](attachment:WhatsApp%20Image%202023-07-14%20at%2010.56.26.jpg)
# ![WhatsApp%20Image%202023-07-14%20at%2010.56.26-2.jpg](attachment:WhatsApp%20Image%202023-07-14%20at%2010.56.26-2.jpg)

# %% [markdown]
# ### Q16. Two groups of students are given different study materials to prepare for a test. The first group (n1 = 30) has a mean score of 80 with a standard deviation of 10, and the second group (n2 = 40) has a mean score of 75 with a standard deviation of 8. Test the hypothesis that the population means for the two groups are equal with a significance level of 0.01.

# %% [markdown]
# ![WhatsApp%20Image%202023-07-14%20at%2010.56.26.jpg](attachment:WhatsApp%20Image%202023-07-14%20at%2010.56.26.jpg)

# %% [markdown]
# ![WhatsApp%20Image%202023-07-14%20at%2010.56.27.jpg](attachment:WhatsApp%20Image%202023-07-14%20at%2010.56.27.jpg)

# %% [markdown]
# ### Q17. A marketing company wants to estimate the average number of ads watched by viewers during a TV program. They take a random sample of 50 viewers and find that the sample mean is 4 with a standard deviation of 1.5. Estimate the population mean with a 99% confidence interval.

# %% [markdown]
# ![WhatsApp%20Image%202023-07-14%20at%2010.56.27.jpg](attachment:WhatsApp%20Image%202023-07-14%20at%2010.56.27.jpg)

# %% [markdown]
# ###

# %% [markdown]
# ###

# %% [markdown]
# ###

# %% [markdown]
# ###

# %% [markdown]
# ###
